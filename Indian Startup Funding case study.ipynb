# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('startup_funding.csv')

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.shape
# Out:
# (3044, 10)

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.sample(5)
# Out:
#       Sr No Date dd/mm/yyyy Startup Name                   Industry Vertical  \
# 2584   2585      06/07/2015  ConfirmtTkt  Rail Ticket Confirmation predictor
# 1405   1406      28/09/2016        Druva                          Technology
# 154     155      04/09/2018       3HCare                          Healthcare
# 2009   2010      05/01/2016  WIMWI Foods                     Food & Beverage
# 2581   2582      04/07/2015       Elanic     P2P Pre-owned goods marketplace
#
#                                      SubVertical City  Location  \
# 2584                                         NaN      Bangalore
# 1405        Cloud Based Data Protection Solution           Pune
# 154                  Healthcare Service Provider          Delhi
# 2009  Healthy food manufacturing & sales startup      Ahmedabad
# 2581                                         NaN      Bangalore
#
#                                          Investors Name       InvestmentnType  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %% [markdown]
# Data Preprocessing

# %%
#drop the remark column
df.drop(columns=['Remarks'],inplace=True)

# %%
#set the index Sr No
df.set_index('Sr No',inplace=True)

# %%
#rename the column
df.rename(columns={
        'Date dd/mm/yyyy':'date',
        'Startup Name':'name',
        'Industry Vertical':'Vertical',
        'SubVertical':'subvertical',
         'City  Location':'city',
         'Investors Name':'investors',
         'InvestmentnType':'round',
        'Amount in USD':'amount'
    },inplace=True)

# %%
df
# Out:
#              date                          name             Vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
#Fill in amount column with zero where is NaN value is present
df['amount']=df['amount'].fillna('0')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   name         3044 non-null   object
#  2   Vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df['amount']=df['amount'].str.replace(',','')

# %%
df['amount']
# Out:
# Sr No
# 1       200000000
# 2         8048394
# 3        18358860
# 4         3000000
# 5         1800000
#           ...
# 3040      4500000
# 3041       825000
# 3042      1500000
# 3043            0
# 3044       140000
# Name: amount, Length: 3044, dtype: object

# %%
df['amount'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['amount'].value_counts()
# Out:
# amount
# 0                     960
# 1000000               166
# 500000                108
# 2000000                69
# 5000000                66
#                      ...
# 4850000                 1
# 790000                  1
# \\xc2\\xa010000000      1
# \\xc2\\xa05000000       1
# \\xc2\\xa019350000      1
# Name: count, Length: 466, dtype: int64

# %%
df['amount']=df['amount'].str.replace('undisclosed','0')
df['amount']=df['amount'].str.replace('unknown','0')
df['amount']=df['amount'].str.replace('Undisclosed','0')

# %%
df=df[df['amount'].str.isdigit()]

# %%
df['amount']=df['amount'].astype('float')
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_6292\3595834934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].astype('float')

# %%
df.sample(4)
# Out:
#              date     name           Vertical                subvertical  \
# Sr No
# 366    12/02/2018     Wydr  Consumer Internet            B2B Marketplace
# 604    14/09/2017  Gurukul  Consumer Internet  co-working space provider
# 252    26/06/2018    Paytm         Technology   Digital Payment Platform
# 824    16/05/2017  Niki.ai         Technology           AI-based chatbot
#
#             city                                          investors  \
# Sr No
# 366     Gurugram  Bessemer Venture Partners, Stellaris Venture P...
# 604    New Delhi  Rohit Nanda, Rajit Nanda, Smarak Bhuyan, Sashw...
# 252        Noida                              One 97 Communications
# 824    Bangalore                                                SAP
#
#                 round     amount
# Sr No
# 366    Private Equity        0.0
# 604      Seed Funding        0.0
# 252    Private Equity  8950000.0
# 824    Private Equity        0.0

# %%
#USD to INR
def to_inr(doller):
    inr=doller*82.85
    return inr/10000000

# %%
to_inr(1)
# Out:
# 8.285e-06

# %%
df['amount']=df['amount'].apply(to_inr)
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_6292\4236546661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].apply(to_inr)

# %%
df
# Out:
#              date                          name             Vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df.head()
# Out:
#              date                          name             Vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1657.000000
# ...

# %%
df['date']=df['date'].str.replace("05/072018","05/07/2018")
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_6292\4188022355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']=df['date'].str.replace("05/072018","05/07/2018")

# %%
pd.to_datetime(df['date'],format='%d/%m/%Y',errors='coerce')
# Out:
# Sr No
# 1      2020-01-09
# 2      2020-01-13
# 3      2020-01-09
# 4      2020-01-02
# 5      2020-01-02
#           ...
# 3040   2015-01-29
# 3041   2015-01-29
# 3042   2015-01-30
# 3043   2015-01-30
# 3044   2015-01-31
# Name: date, Length: 3029, dtype: datetime64[ns]

# %%
df['date']=pd.to_datetime(df['date'],format='%d/%m/%Y',errors='coerce')
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_6292\2733850770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']=pd.to_datetime(df['date'],format='%d/%m/%Y',errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3023 non-null   datetime64[ns]
#  1   name         3029 non-null   object
#  2   Vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df=df.dropna(subset=['date','name','Vertical','city','investors','round','amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2819 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2819 non-null   datetime64[ns]
#  1   name         2819 non-null   object
#  2   Vertical     2819 non-null   object
#  3   subvertical  2078 non-null   object
#  4   city         2819 non-null   object
#  5   investors    2819 non-null   object
#  6   round        2819 non-null   object
#  7   amount       2819 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 198.2+ KB

# %%
df['investors'].str.split(',')
# Out:
# Sr No
# 1                               [Tiger Global Management]
# 2                             [Susquehanna Growth Equity]
# 3                                 [Sequoia Capital India]
# 4                                        [Vinod Khatumal]
# 5                               [Sprout Venture Partners]
#                               ...
# 2869                                      [SAIF Partners]
# 2870    [Sumit Jain,  Aprameya Radhakrishna,  Alok Goe...
# 2871                                         [Rainmatter]
# 2872                                        [The HR Fund]
# 2873          [Bessemer Venture Partners,  SAIF Partners]
# Name: investors, Length: 2819, dtype: object

# %%
df['investors'].str.split(',').sum()
# Out:
# ['Tiger Global Management',
#  'Susquehanna Growth Equity',
#  'Sequoia Capital India',
#  'Vinod Khatumal',
#  'Sprout Venture Partners',
#  'Chiratae Ventures',
#  'Ant Financial',
#  'Sathguru Catalyzer Advisors',
#  'Ping An Global Voyager Fund',
#  'Mumbai Angels',
#  ' Ravikanth Reddy',
#  'SAIF Partners',
#  ' Spring Canter Investment Ltd.',
#  'Paytm',
#  ' NPTK',
#  ' Sabre Partners and Neoplux',
#  'Vertex Growth Fund',
#  'Ruizheng Investment',
#  'Manipal Education and Medical Group (MEMG)',
#  'SoftBank Vision Fund',
#  'Sequoia',
#  ' CapitalG',
#  ' Accel',
#  'Sauce.vc',
#  ' Rainforest Ventures',
#  'Prime Venture Partners',
#  ' LetsVenture',
#  ' PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  'RB Investments',
#  'DG Daiwa Ventures',
#  ' DG Incubation',
#  'Trifecta Capital Advisors',
#  'FinTech',
#  'Dream Incubator',
#  'Altimeter Capital',
#  ' Sutter Hill Ventures',
#  'Startup Buddy',
#  'Amour Infrastructure',
#  'Ackermans & van Haaren',
# ...

# %%
set(df['investors'].str.split(',').sum())
# Out:
# {'',
#  'Mohit Gulati',
#  ' Imanpreet Singh Arora',
#  ' SEGNEL Ventures',
#  '\\\\xc2\\\\xa0 Sandeep Tandon',
#  ' Techstars Ventures & Others',
#  '\\\\xc2\\\\xa0 Capital Advisers',
#  'Karanpal Singh',
#  'Kalaari Capital',
#  'Cross Border Angels & others',
#  ' Singapore Angel Network.',
#  'Labruyere Eberl\\\\xc3\\\\xa9',
#  ' Ontario Teachers\\\\\'"',
#  'Mahalingam K',
#  'Blume Ventures',
#  'Rising Stars',
#  ' Vinay Mittal',
#  'GAIN',
#  '50k Ventures',
#  ' Pankaj Tripathi',
#  'Omphalos Ventures India LLP',
#  ' Harsh Kundra',
#  ' Hiro Mashita',
#  'Unnamed angel investors',
#  ' Amaya Capital LLP',
#  ' SD Ventures',
#  ' Cheetah Mobile',
#  ' Pravin Dongre',
#  'Aequs Group',
#  ' Axis Bank',
#  ' Hinduja Leyland Finance and IntelleGrow',
#  'GMO Japan',
#  'Infosys',
#  'Lead Angels Network',
#  'KWAN Entertainment & Marketing Solutions',
#  'Francesco Cara',
#  'Network 18',
#  ' Prashant Malik and others',
#  ' Amit Khanna (LetsVenture)',
# ...

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df
# Out:
#             date                          name                    Vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
df.to_csv('stratuo_cleaned.csv')

# %%
df['investors'].str.contains('Tiger Global Management')
# Out:
# Sr No
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 2869    False
# 2870    False
# 2871    False
# 2872    False
# 2873    False
# Name: investors, Length: 2819, dtype: bool

# %%
df[df['investors'].str.contains('Tiger Global Management')].head()[['date','name','Vertical','city','round','amount']]
# Out:
#             date       name    Vertical       city                 round  \
# Sr No
# 1     2020-01-09     BYJU’S      E-Tech  Bengaluru  Private Equity Round
# 56    2019-08-22  INDwealth     FinTech    Gurgaon         Venture Round
# 69    2019-07-11     Moglix  E-Commerce  Singapore              Series D
# 86    2019-06-10   OkCredit     FinTech    Haryana              Series A
# 94    2019-05-02     Zenoti        Saas  Hyderabad              Series C
#
#           amount
# Sr No
# 1      1657.0000
# 56      124.2750
# 69      497.1000
# 86      128.4175
# 94      414.2500

# %%
df[df['investors'].str.contains('FAO Ventures')]
# Out:
#             date      name   Vertical                 subvertical   city  \
# Sr No
# 1291  2016-10-13  FabAlley  ecommerce  online fashion brand store  Noida
#
#                                                investors           round  \
# Sr No
# 1291   India Quotient, FAO Ventures, Indian Angel Net...  Private Equity
#
#        amount
# Sr No
# 1291    16.57

# %%
df[df['investors'].str.contains('Sequoia Capital India')].groupby('name')['amount'].sum().sort_values(ascending=False).head()
# Out:
# name
# OYO Rooms    2071.250
# Oyo Rooms    2071.250
# Dhruva        662.800
# Moglix        497.100
# FreshDesk     455.675
# Name: amount, dtype: float64

# %%
df[df['name'].str.contains('BYJU’S')]
# Out:
#             date    name Vertical subvertical       city  \
# Sr No
# 1     2020-01-09  BYJU’S   E-Tech  E-learning  Bengaluru
#
#                      investors                 round  amount
# Sr No
# 1      Tiger Global Management  Private Equity Round  1657.0

# %%
df[df['investors'].str.contains('Tiger Global Management')].groupby('Vertical')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['investors'].str.contains('Tiger Global Management')].groupby('round')['amount'].sum()
# Out:
# round
# Private Equity          3959.4015
# Private Equity Round    1657.0000
# Series A                 128.4175
# Series B                 215.4100
# Series C                 414.2500
# Series D                 497.1000
# Venture Round            124.2750
# Name: amount, dtype: float64

# %%
df
# Out:
#             date                          name                    Vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
df['year']=df['date'].dt.year
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_6292\2063528821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=df['date'].dt.year

# %%
df[df['investors'].str.contains('Rainmatter')].groupby('year')['amount'].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
round(df['amount'].sum())
# Out:
# 297729

# %%
round(df['amount'].max())
# Out:
# 32312

# %%
df[df['amount']==32311.5]
# Out:
#             date              name        Vertical subvertical       city  \
# Sr No
# 61    2019-08-27  Rapido Bike Taxi  Transportation   Bike Taxi  Bengaluru
#
#                 investors     round   amount  year
# Sr No
# 61     Westbridge Capital  Series B  32311.5  2019

# %%
df['amount'].max()
# Out:
# np.float64(32311.5)

# %%
df.groupby('name')['amount'].max().sort_values(ascending=False).head(1).values[0].item()
# Out:
# 32311.5

# %%
round(df.groupby('name')['amount'].sum().mean())
# Out:
# 130

# %%
df['name'].nunique()
# Out:
# 2297

# %%
df
# Out:
#             date                          name                    Vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
df['month']=df['date'].dt.month
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_6292\4289079944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month']=df['date'].dt.month

# %%
df
# Out:
#             date                          name                    Vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
temp_df=df.groupby(['year','month'])['amount'].sum().reset_index()

# %%
temp_df['x_axis']=temp_df['month'].astype('str') + '-' + temp_df['year'].astype('str')

# %%
temp_df
# Out:
#     year  month        amount   x_axis
# 0   2015      4   8115.157500   4-2015
# 1   2015      5   2652.318475   5-2015
# 2   2015      6   4320.577790   6-2015
# 3   2015      7  12503.655720   7-2015
# 4   2015      8   8813.715560   8-2015
# 5   2015      9  12174.973200   9-2015
# 6   2015     10   2112.351885  10-2015
# 7   2015     11   7431.272175  11-2015
# 8   2015     12   2533.992105  12-2015
# 9   2016      1   5798.505800   1-2016
# 10  2016      2   2746.398792   2-2016
# 11  2016      3   2564.717922   3-2016
# 12  2016      4   2103.892900   4-2016
# 13  2016      5   2815.574400   5-2016
# 14  2016      6   1654.009115   6-2016
# 15  2016      7   1934.936895   7-2016
# 16  2016      8   4424.927365   8-2016
# 17  2016      9   1999.675885   9-2016
# 18  2016     10   1967.256680  10-2016
# 19  2016     11   2154.075145  11-2016
# 20  2016     12   1551.308255  12-2016
# 21  2017      1   2098.039548   1-2017
# 22  2017      2   2443.735315   2-2017
# ...
